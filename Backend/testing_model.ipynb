# %%
import numpy as np 
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
from random import shuffle
from keras.utils  import to_categorical 
import pickle
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop

# %%
from keras import models
model = models.load_model('new.h5')

# %%
def check_defection(fruit):
    p = model.predict_classes(fruit.reshape(1,100,100,3))
    if p==[0]:
        print("Fresh")
    else:
        print("Defected")

# %%
img = cv2.imread("picx\home1.png")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
check_defection(X)
# Out:
# Fresh

# %%
X=np.array(img)
X=X/255.0
check_defection(X)
# Out:
# Fresh

# %%
img = cv2.imread("picx\home2.png")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
check_defection(X)
# Out:
# Defected

# %%
img = cv2.imread("home3.jpeg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
check_defection(X)
# Out:
# Fresh

# %%
img = cv2.imread("banana_t.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
check_defection(X)
# Out:
# Defected

# %%
img = cv2.imread("rotno.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
check_defection(X)
# Out:
# Fresh
