# %%
import numpy as np 
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
from random import shuffle
from keras.utils  import to_categorical
import tensorflow as tf
import pickle

# %%
def load_rottenvsfresh():
    quality=['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
    X,Y=[],[]
    z=[]
    for cata in tqdm(os.listdir('train')):
        if quality[0] in cata:
            path_main=os.path.join('train',cata)
            for img_name in os.listdir(path_main):
                img=cv2.imread(os.path.join(path_main,img_name))
                img=cv2.resize(img,(100,100))
                img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                z.append([img,0])
        elif quality[1] in cata:
            path_main=os.path.join('train',cata)
            for img_name in os.listdir(path_main):
                img=cv2.imread(os.path.join(path_main,img_name))
                img=cv2.resize(img,(100,100))
                img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                z.append([img,1])
        elif quality[2] in cata:
            path_main=os.path.join('train',cata)
            for img_name in os.listdir(path_main):
                img=cv2.imread(os.path.join(path_main,img_name))
                img=cv2.resize(img,(100,100))
                img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                z.append([img,2])
        elif quality[3] in cata:
            path_main=os.path.join('train',cata)
            for img_name in os.listdir(path_main):
                img=cv2.imread(os.path.join(path_main,img_name))
                img=cv2.resize(img,(100,100))
                img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                z.append([img,3])
        elif quality[4] in cata:
            path_main=os.path.join('train',cata)
            for img_name in os.listdir(path_main):
                img=cv2.imread(os.path.join(path_main,img_name))
                img=cv2.resize(img,(100,100))
                img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                z.append([img,4])
        else:
            path_main=os.path.join('train',cata)
            for img_name in os.listdir(path_main):
                img=cv2.imread(os.path.join(path_main,img_name))
                img=cv2.resize(img,(100,100))
                img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                z.append([img,5])
    print('Shuffling data.....')
    shuffle(z)
    for images, labels in tqdm(z):
        X.append(images);Y.append(labels)
    return X,Y

# %%
X,Y=load_rottenvsfresh()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [05:09<00:00, 51.53s/it]
# 100%|████████████████████████████████████████████████████████████████████████| 10901/10901 [00:00<00:00, 380238.08it/s]
# Shuffling data.....

# %%
from collections import Counter
Y=np.array(Y)
X=np.array(X)
newData = Counter(Y)
most_fruits = newData.most_common(6)
most_fruits
# Out:
# [(3, 2342), (4, 2224), (0, 1693), (5, 1595), (1, 1581), (2, 1466)]

# %%
X.shape
# Out:
# (10901, 100, 100, 3)

# %%
def load_rottenvsfresh_test_valset():
    quality=['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
    X,Y=[],[]
    z=[]
    for cata in tqdm(os.listdir('test')):
        if quality[0] in cata:
            path_main=os.path.join('test',cata)
            for img_name in os.listdir(path_main):
                img=cv2.imread(os.path.join(path_main,img_name))
                img=cv2.resize(img,(100,100))
                img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                z.append([img,0])
        elif quality[1] in cata:
            path_main=os.path.join('test',cata)
            for img_name in os.listdir(path_main):
                img=cv2.imread(os.path.join(path_main,img_name))
                img=cv2.resize(img,(100,100))
                img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                z.append([img,1])
        elif quality[2] in cata:
            path_main=os.path.join('test',cata)
            for img_name in os.listdir(path_main):
                img=cv2.imread(os.path.join(path_main,img_name))
                img=cv2.resize(img,(100,100))
                img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                z.append([img,2])
        elif quality[3] in cata:
            path_main=os.path.join('test',cata)
            for img_name in os.listdir(path_main):
                img=cv2.imread(os.path.join(path_main,img_name))
                img=cv2.resize(img,(100,100))
                img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                z.append([img,3])
        elif quality[4] in cata:
            path_main=os.path.join('test',cata)
            for img_name in os.listdir(path_main):
                img=cv2.imread(os.path.join(path_main,img_name))
                img=cv2.resize(img,(100,100))
                img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                z.append([img,4])
        else:
            path_main=os.path.join('test',cata)
            for img_name in os.listdir(path_main):
                img=cv2.imread(os.path.join(path_main,img_name))
                img=cv2.resize(img,(100,100))
                img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                z.append([img,5])
    print('Shuffling data.....')
    shuffle(z)
    for images, labels in tqdm(z):
        X.append(images);Y.append(labels)
    return X,Y

# %%
X_val,Y_val=load_rottenvsfresh_test_valset()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [01:22<00:00, 13.80s/it]
# 100%|██████████████████████████████████████████████████████████████████████████| 2698/2698 [00:00<00:00, 465918.65it/s]
# Shuffling data.....

# %%
Y_val=np.array(Y_val)
X_val=np.array(X_val)
newData = Counter(Y_val)
most_fruits = newData.most_common(6)
most_fruits
# Out:
# [(3, 601), (4, 530), (5, 403), (0, 395), (2, 388), (1, 381)]

# %%
X=X/255.0
X_val=X_val/255.0

# %%
Y=to_categorical(Y)
Y_val=to_categorical(Y_val)

# %%
Y.shape, Y_val.shape
# Out:
# ((10901, 6), (2698, 6))

# %%
import keras 
from keras.layers import Dense,Dropout, Conv2D,MaxPooling2D , Activation, Flatten, BatchNormalization, SeparableConv2D
from keras.models import Sequential

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), kernel_initializer='he_uniform', padding='same', activation='relu', input_shape=(100,100,3)))
#model.add(BatchNormalization())
#model.add(SeparableConv2D(32, (3, 3), kernel_initializer='he_uniform', padding='same', activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(SeparableConv2D(64, (3, 3), kernel_initializer='he_uniform', padding='same', activation='relu'))
#model.add(SeparableConv2D(64, (3, 3), kernel_initializer='he_uniform', padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))

model.add(SeparableConv2D(128, (3, 3), kernel_initializer='he_uniform', padding='same', activation='relu'))
#model.add(SeparableConv2D(128, (3, 3), kernel_initializer='he_uniform', padding='same', activation='relu'))
#model.add(BatchNormalization())
#model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Flatten())

model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(Dropout(0.5))

model.add(Dense(6, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 100, 100, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 50, 50, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 50, 50, 32)        0
# _________________________________________________________________
# separable_conv2d (SeparableC (None, 50, 50, 64)        2400
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 50, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25, 25, 64)        0
# _________________________________________________________________
# separable_conv2d_1 (Separabl (None, 25, 25, 128)       8896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 25, 25, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 80000)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               10240128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 10,253,478
# Trainable params: 10,253,286
# Non-trainable params: 192
# _________________________________________________________________

# %%
lr_rate=keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=6, verbose=1, mode='max',
    min_lr=0.00002, cooldown=2)
check_point=tf.keras.callbacks.ModelCheckpoint(
    filepath='fruit.h5', monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=False, mode='min')

# %%
model.compile(loss=keras.losses.categorical_crossentropy, optimizer = keras.optimizers.Adam(lr = 0.001), metrics=['accuracy'])

# %%
history=model.fit(X,Y,batch_size=20,validation_data=(X_val,Y_val),epochs= 30,
                 callbacks=[check_point])
# Out:
# Epoch 1/30
# 546/546 [==============================] - 304s 526ms/step - loss: 1.2722 - accuracy: 0.5764 - val_loss: 0.7083 - val_accuracy: 0.7887
#
# Epoch 00001: val_loss improved from inf to 0.70826, saving model to fruit.h5
# Epoch 2/30
# 546/546 [==============================] - 238s 434ms/step - loss: 0.4965 - accuracy: 0.8210 - val_loss: 0.3741 - val_accuracy: 0.8625
#
# Epoch 00002: val_loss improved from 0.70826 to 0.37410, saving model to fruit.h5
# Epoch 3/30
# 546/546 [==============================] - 228s 418ms/step - loss: 0.4025 - accuracy: 0.8490 - val_loss: 0.6760 - val_accuracy: 0.8006
#
# Epoch 00003: val_loss did not improve from 0.37410
# Epoch 4/30
# 546/546 [==============================] - 244s 447ms/step - loss: 0.3145 - accuracy: 0.8868 - val_loss: 0.2298 - val_accuracy: 0.9144
#
# Epoch 00004: val_loss improved from 0.37410 to 0.22976, saving model to fruit.h5
# Epoch 5/30
# 546/546 [==============================] - 241s 441ms/step - loss: 0.3628 - accuracy: 0.8679 - val_loss: 0.1886 - val_accuracy: 0.9437
#
# Epoch 00005: val_loss improved from 0.22976 to 0.18863, saving model to fruit.h5
# Epoch 6/30
# 546/546 [==============================] - 240s 440ms/step - loss: 0.2398 - accuracy: 0.9083 - val_loss: 0.1793 - val_accuracy: 0.9422
#
# Epoch 00006: val_loss improved from 0.18863 to 0.17931, saving model to fruit.h5
# Epoch 7/30
# 546/546 [==============================] - 237s 435ms/step - loss: 0.2197 - accuracy: 0.9235 - val_loss: 0.1296 - val_accuracy: 0.9540
#
# Epoch 00007: val_loss improved from 0.17931 to 0.12965, saving model to fruit.h5
# Epoch 8/30
# 546/546 [==============================] - 239s 437ms/step - loss: 0.2023 - accuracy: 0.9278 - val_loss: 0.1380 - val_accuracy: 0.9596
#
# Epoch 00008: val_loss did not improve from 0.12965
# Epoch 9/30
# 546/546 [==============================] - 230s 421ms/step - loss: 0.2313 - accuracy: 0.9152 - val_loss: 0.1151 - val_accuracy: 0.9596
#
# Epoch 00009: val_loss improved from 0.12965 to 0.11510, saving model to fruit.h5
# Epoch 10/30
# 546/546 [==============================] - 245s 449ms/step - loss: 0.1775 - accuracy: 0.9355 - val_loss: 0.1978 - val_accuracy: 0.9362
#
# Epoch 00010: val_loss did not improve from 0.11510
# Epoch 11/30
# 546/546 [==============================] - 240s 440ms/step - loss: 0.2831 - accuracy: 0.8991 - val_loss: 0.1842 - val_accuracy: 0.9437
#
# Epoch 00011: val_loss did not improve from 0.11510
# Epoch 12/30
# 546/546 [==============================] - 236s 433ms/step - loss: 0.1495 - accuracy: 0.9464 - val_loss: 0.1616 - val_accuracy: 0.9485
#
# Epoch 00012: val_loss did not improve from 0.11510
# Epoch 13/30
# 546/546 [==============================] - 237s 435ms/step - loss: 0.1550 - accuracy: 0.9456 - val_loss: 0.0924 - val_accuracy: 0.9711
#
# Epoch 00013: val_loss improved from 0.11510 to 0.09242, saving model to fruit.h5
# Epoch 14/30
# 546/546 [==============================] - 239s 438ms/step - loss: 0.1295 - accuracy: 0.9519 - val_loss: 0.1656 - val_accuracy: 0.9518
#
# Epoch 00014: val_loss did not improve from 0.09242
# Epoch 15/30
# 546/546 [==============================] - 251s 460ms/step - loss: 0.1383 - accuracy: 0.9479 - val_loss: 0.0936 - val_accuracy: 0.9685
#
# Epoch 00015: val_loss did not improve from 0.09242
# Epoch 16/30
# 546/546 [==============================] - 237s 435ms/step - loss: 0.1192 - accuracy: 0.9598 - val_loss: 0.2365 - val_accuracy: 0.9329
#
# Epoch 00016: val_loss did not improve from 0.09242
# Epoch 17/30
# 546/546 [==============================] - 238s 436ms/step - loss: 0.1054 - accuracy: 0.9634 - val_loss: 0.2848 - val_accuracy: 0.9381
#
# Epoch 00017: val_loss did not improve from 0.09242
# Epoch 18/30
# 546/546 [==============================] - 251s 461ms/step - loss: 0.1109 - accuracy: 0.9594 - val_loss: 0.1090 - val_accuracy: 0.9778
#
# Epoch 00018: val_loss did not improve from 0.09242
# Epoch 19/30
# 546/546 [==============================] - 251s 459ms/step - loss: 0.1006 - accuracy: 0.9620 - val_loss: 0.0644 - val_accuracy: 0.9807
#
# Epoch 00019: val_loss improved from 0.09242 to 0.06444, saving model to fruit.h5
# Epoch 20/30
# 546/546 [==============================] - 240s 439ms/step - loss: 0.0991 - accuracy: 0.9619 - val_loss: 0.1218 - val_accuracy: 0.9622
#
# Epoch 00020: val_loss did not improve from 0.06444
# Epoch 21/30
# 546/546 [==============================] - 245s 449ms/step - loss: 0.0871 - accuracy: 0.9688 - val_loss: 0.0883 - val_accuracy: 0.9733
#
# Epoch 00021: val_loss did not improve from 0.06444
# Epoch 22/30
# 546/546 [==============================] - 255s 466ms/step - loss: 0.0789 - accuracy: 0.9701 - val_loss: 0.2569 - val_accuracy: 0.9500
#
# Epoch 00022: val_loss did not improve from 0.06444
# Epoch 23/30
# 546/546 [==============================] - 235s 431ms/step - loss: 0.0846 - accuracy: 0.9691 - val_loss: 0.0538 - val_accuracy: 0.9893
#
# Epoch 00023: val_loss improved from 0.06444 to 0.05375, saving model to fruit.h5
# Epoch 24/30
# 546/546 [==============================] - 236s 432ms/step - loss: 0.0660 - accuracy: 0.9753 - val_loss: 0.0747 - val_accuracy: 0.9763
#
# Epoch 00024: val_loss did not improve from 0.05375
# Epoch 25/30
# 546/546 [==============================] - 238s 435ms/step - loss: 0.0686 - accuracy: 0.9716 - val_loss: 0.0490 - val_accuracy: 0.9867
#
# Epoch 00025: val_loss improved from 0.05375 to 0.04901, saving model to fruit.h5
# Epoch 26/30
# 546/546 [==============================] - 238s 436ms/step - loss: 0.1409 - accuracy: 0.9593 - val_loss: 0.0573 - val_accuracy: 0.9863
#
# Epoch 00026: val_loss did not improve from 0.04901
# Epoch 27/30
# 546/546 [==============================] - 239s 439ms/step - loss: 0.0640 - accuracy: 0.9793 - val_loss: 0.4072 - val_accuracy: 0.9277
#
# Epoch 00027: val_loss did not improve from 0.04901
# Epoch 28/30
# 546/546 [==============================] - 246s 450ms/step - loss: 0.0529 - accuracy: 0.9808 - val_loss: 0.0831 - val_accuracy: 0.9830
#
# Epoch 00028: val_loss did not improve from 0.04901
# Epoch 29/30
# 546/546 [==============================] - 244s 448ms/step - loss: 0.0545 - accuracy: 0.9810 - val_loss: 0.0847 - val_accuracy: 0.9811
#
# Epoch 00029: val_loss did not improve from 0.04901
# Epoch 30/30
# 546/546 [==============================] - 241s 442ms/step - loss: 0.0635 - accuracy: 0.9775 - val_loss: 0.0477 - val_accuracy: 0.9881
#
# Epoch 00030: val_loss improved from 0.04901 to 0.04771, saving model to fruit.h5

# %%
plt.figure(1, figsize = (8, 4))
plt.plot()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot( history.history["loss"], label = "Training Loss")
plt.plot( history.history["val_loss"], label = "Validation Loss")
plt.grid(True)
plt.legend()

# %%
plt.figure(1, figsize = (8, 4))
plt.plot()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot( history.history["accuracy"], label = "Training Accuracy")
plt.plot( history.history["val_accuracy"], label = "Validation Accuracy")
plt.grid(True)
plt.legend()

# %%
model.evaluate(X_val,Y_val)
# Out:
# 85/85 [==============================] - 10s 115ms/step - loss: 0.0477 - accuracy: 0.9881
# [0.047708768397569656, 0.9881393909454346]

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
plt.imshow(X_val[0])

# %%
model.predict_classes(X_val[0].reshape(1,100,100,3))
# Out:
# D:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# array([4], dtype=int64)

# %%
import numpy as np 
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
from random import shuffle
from keras.utils  import to_categorical 
import pickle
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop

# %%
from keras import models
model = models.load_model('fruit.h5')

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("banana2.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([4], dtype=int64)

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("apple2.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([0], dtype=int64)

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("apple1.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([3], dtype=int64)

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("or2.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
model.predict_classes(X.reshape(1,100,100,3))
# Out:
# D:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# array([3], dtype=int64)

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("or3.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([3], dtype=int64)

# %%
from keras import models
n_model = models.load_model('fruit_classification.h5')

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("or3.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
n_model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([2], dtype=int64)

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("or2.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
n_model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([5], dtype=int64)

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("or.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
n_model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([2], dtype=int64)

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("or1.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
n_model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([2], dtype=int64)

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("apple1.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
n_model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([3], dtype=int64)

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("apple3.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
n_model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([3], dtype=int64)

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("rez.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
n_model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([4], dtype=int64)

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("ban.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
n_model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([4], dtype=int64)

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("banana2.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
n_model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([4], dtype=int64)

# %%
#['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']
img = cv2.imread("rez_Ap1.jpg")
img=cv2.resize(img,(100,100))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
X=np.array(img)
X=X/255.0
n_model.predict_classes(X.reshape(1,100,100,3))
# Out:
# array([0], dtype=int64)
